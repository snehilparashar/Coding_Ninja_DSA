# %% [markdown]
# ### Implementing stack using array

# %%
class stack:
    
    def __init__(self,data):
        
        self.__data = []
        
    def push(self,item):
        
        self.__data.append(item)
        
    def sizeofstack(self):
        
        return len(self.__data)
    
    def isemptystack(self):
        
        if len(self.__data) == 0:
            return True
        else:
            return False
        
    def pop(self):
        
        if isemptystack: #This means that the stack is empty
            print("The stack is empty")
            return
        else:
            return self.__data.pop() #Using the built in pop function
        
    def top(self):
        
        n = len(self.__data)
        
        if n ==0:
            print("The stack is empty")
            return
        
        return self.__data[n-1]

# %% [markdown]
# ### Implementing stack using LinkedList

# %%
class Node:
    
    def __init__(self,data):
        
        self.data = data
        self.next = None
        
class stack:
    
    
    def __init__(self):
        self.__head = None
        self.__count = 0
        
        
    def push(self,element):
        
        newNode = Node(element)
        
        newNode.next = self.__head
        self.__head = newNode
        self.__count = self.__count + 1
        
    def pop(self):
        
        if isemptystack:
            print("the stack seems to be empty")
            return
        
        topdata = self.__head.data
        self.__head = self.__head.next
        self.__count = self.__count - 1
        
        return topdata
    
    def top(self):
        return self.__head.data
        
    def size(self):
        
        if isemptystack:
            print("the stack seems to be empty")
            return
        
        return self.__count
    
    def isempty(self):
        
        if self.__count == 0:
            return True
        else:
            return False

# %% [markdown]
# ### reverse stack

# %%
def reversestack(s1,s2):
    
    if len(s1) <= 1:
        return 
    
    while len(s1) != 1:
        element = si.pop()
        s2.append(element)
        
    lastelement = s1.pop()
    
    while len(s2) != 0:
        element = s2.pop()
        s1.append(element)
        
    reversestack(s1,s2)
    
    return s1.append(lastelement)

# %% [markdown]
# ### Queue using an array

# %%
class Queueusingarray:
    
    def __init__(self):
        self.__array = []
        self.__count = 0
        self.__frontelemet = 0
        
    def enqueue(self,element):
        self.__array.append(element)
        self.__count = self.__count + 1
        
    def front(self):
        
        if self.__frontelemet == 0:
            return -1
        return self.__array[self.__frontelemet]
    
    def dequeu(self):
        
        if self.__frontelemet == 0:
            return -1
        
        element = self.__array[self.__frontelemet]
        
        self.__frontelemet = self.__front + 1
        self.__count = self.count -1
        
        return element
    
    def size(self):
        
        return self.__count
    
    def isempty(self):
        
        if self.__count == 0:
            print("The Queue is empty")
            return
        return

# %% [markdown]
# ### Stack using LinkedList

# %%
class Node:
    
    def __init__(self,data):
        self.data = data
        self.next = None
        
class StackusingLinkedList:
    
    def __init__(self):
        
        self.__head = None
        self.__tail = None
        self.__count = 0
        
        
    def enqueue(self,element):
        
        newNode = Node(element)
        
        if head is None:
            self.__head = newNode
            self.__tail = newNode
            
        else:
            
            self.__tail.next = newNode
            self.__tail = newNode
            
        self.__count = self.__count + 1
        
    def dequeu(self):
        
        if self.__head is None:
            print("The given Queue is empty")
            return
        
        topelement = self.__head
        
        self.__head = self.__head.next
        
        self.__count = self.__count - 1
        
        return topelement
    
    def sizeofQueue(self):
        
        if self.__count == 0:
            print("The Queue is empty")
            return
        
        return self.__count
    
    def topelementofQueue(self):
        
        if self.__count == 0:
            print("The Queue seems to be empty")
            return
        
        data = self.__head.data
        return data
    
    def isempty(self):
        
        return self.__count == 0

# %% [markdown]
# ### Implementing Queue using two stack

# %%
class QueueusingStack:
    
    def __init__(self):
        
        self.__stack1 = []
        self.__stack2 = []
        
    def enqueue(self,element):
        
        while len(self.__stack1) != 0:
            self.__stack2.append(self.__stack1.pop())
            
        self.__stack1.append(element)
        
        while len(self.__stack2) != 0:
            
            self.__stack1.append(self.__stack2.pop())
            
        return self.__stack1
    
    def dequeue(self):
        
        if len(self.__stack1) == 0:
            return -1
        
        return self.__stack1.pop()
    
    def topelement(self):
        
        if len(self.__stack1) == 0:
            return
        
        return self.__stack1[-1]
    
    def sizeofQueue(self):
        
        return len(self.__stack1)
    
    def isempty(self):
        
        if len(self.__stack1) == 0:
            return True
        else:
            return False

# %% [markdown]
# ### Reverse a Queue

# %%
from queue import Queue
def getQueuereversed(inputQueue):
    
    if inputQueue.qsize() <= 1:
        return 
    
    frontelement = inputQueue.get()
    
    getQueuereversed(inputQueue)
    
    inputQueue.put(frontelement)
    
    return inputQueue
